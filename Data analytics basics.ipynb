# %%
# importing all libraries 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy import stats

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# reading a csv file(to do this upload that csv file on jupyter home panel)
df = pd.read_csv("datasets_596958_1073629_Placement_Data_Full_Class.csv")

# %%
# to see only limited data
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
# to see columns
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
#.loc splits the data(only by names of columns and row not by index number)
## variable[particular row, particular column]
### when to choose multiple columns or rows
####variable[[abc row element, xyz row element], [abc column element, xyz columb element]]
#### below down it means we want to show etest_p column with 9 rows in it or simply : for all rows to be shown
df.loc[:9, "etest_p"]
# Out:
# 0    55.00
# 1    86.50
# 2    75.00
# 3    66.00
# 4    96.80
# 5    55.00
# 6    74.28
# 7    67.00
# 8    91.34
# 9    54.00
# Name: etest_p, dtype: float64

# %%
df.loc[:, "etest_p"]
# Out:
# 0      55.00
# 1      86.50
# 2      75.00
# 3      66.00
# 4      96.80
# 5      55.00
# 6      74.28
# 7      67.00
# 8      91.34
# 9      54.00
# 10     62.00
# 11     60.00
# 12     62.00
# 13     68.00
# 14     76.00
# 15     72.00
# 16     60.00
# 17     60.00
# 18     68.00
# 19     50.48
# 20     50.00
# 21     95.00
# 22     55.53
# 23     92.00
# 24     97.40
# 25     76.00
# 26     94.00
# 27     68.00
# 28     73.35
# 29     77.00
# 30     52.00
# 31     64.00
# 32     50.89
# 33     88.00
# 34     68.44
# 35     71.00
# 36     64.00
# 37     58.00
# 38     53.70
# 39     93.00
# 40     60.00
# 41     65.00
# 42     63.00
# 43     95.00
# 44     89.00
# 45     58.00
# 46     68.00
# 47     78.00
# 48     64.00
# 49     65.00
# 50     65.00
# 51     67.00
# 52     71.20
# 53     87.00
# 54     78.00
# 55     71.00
# 56     68.00
# 57     80.00
# 58     74.00
# 59     57.60
# 60     60.00
# 61     61.60
# 62     59.00
# 63     68.50
# 64     61.00
# 65     89.69
# ...

# %%
#iloc method use index number(row number, columnn number)
df.iloc[:4]
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN

# %%
df.loc[2:4]
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 2      3      M   65.0  Central   68.0  Central      Arts      64.0
# 3      4      M   56.0  Central   52.0  Central   Science      52.0
# 4      5      M   85.8  Central   73.6  Central  Commerce      73.3
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
# to get unique values in df in particular row/column
## as output it will give us a array
df.degree_t.unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
# example: to to count how many students is placed (from data)
## this method is used to count how many times different elements are repeated in that particular row or column
df.loc[:, "status"]
df.groupby("status").size()
# Out:
# status
# Not Placed     67
# Placed        148
# dtype: int64

# %%
df.loc[:, "hsc_p"]
df.groupby("hsc_p").size()
# Out:
# hsc_p
# 37.00     1
# 39.00     1
# 40.00     1
# 42.00     1
# 42.16     1
# 44.00     1
# 45.83     1
# 47.00     4
# 49.00     1
# 49.20     1
# 49.80     1
# 50.00     2
# 50.83     1
# 51.00     4
# 52.00     2
# 53.00     2
# 54.00     1
# 54.60     1
# 55.00     2
# 56.00     2
# 57.00     3
# 58.00     4
# 58.66     1
# 59.00     3
# 60.00     9
# 60.33     1
# 60.50     1
# 60.80     1
# 61.00     6
# 61.12     1
# 61.33     1
# 61.40     1
# 62.00    12
# 62.50     2
# 62.83     1
# 63.00    14
# 63.16     1
# 64.00     8
# 64.20     1
# 64.80     2
# 64.89     1
# 65.00     6
# 65.50     1
# 65.58     1
# 65.66     1
# 66.00     2
# 66.20     1
# 66.60     1
# 66.80     1
# 67.00     9
# 67.20     1
# 68.00     4
# 68.40     2
# 69.00     1
# 69.40     1
# 70.00     8
# 70.20     1
# 70.29     1
# 70.40     1
# 71.00     1
# 71.40     1
# 71.50     1
# 71.98     1
# 72.00     3
# 72.50     1
# 72.80     1
# 73.00     6
# 73.20     1
# 73.40     2
# 73.50     1
# ...

# %%
#how many rows nd columns
df.shape
# Out:
# (215, 15)

# %%
# to find out how many missing n non-missing values
print(pd.isnull(df).sum())
print(pd.notnull(df).sum())
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64
# sl_no             215
# gender            215
# ssc_p             215
# ssc_b             215
# hsc_p             215
# hsc_b             215
# hsc_s             215
# degree_p          215
# degree_t          215
# workex            215
# etest_p           215
# specialisation    215
# mba_p             215
# status            215
# salary            148
# dtype: int64

# %%
#in particular column say salary
print(pd.isnull(df.salary).sum())
print(pd.notnull(df.salary).sum())
# Out:
# 67
# 148

# %%
#to calulate cumulative frequency of each nd every column
np.cumsum(df)
# Out:
#      sl_no                                             gender     ssc_p  \
# 0        1                                                  M     67.00
# 1        3                                                 MM    146.33
# 2        6                                                MMM    211.33
# 3       10                                               MMMM    267.33
# 4       15                                              MMMMM    353.13
# 5       21                                             MMMMMM    408.13
# 6       28                                            MMMMMMF    454.13
# 7       36                                           MMMMMMFM    536.13
# 8       45                                          MMMMMMFMM    609.13
# 9       55                                         MMMMMMFMMM    667.13
# 10      66                                        MMMMMMFMMMM    725.13
# 11      78                                       MMMMMMFMMMMM    794.73
# ...

# %%
#Compute sum
df.sum()
# Out:
# sl_no                                                         23220
# gender            MMMMMMFMMMMMFFMFMFFMMFFFMFMMMMFFFFMFMFFMFFMMFF...
# ssc_p                                                       14470.2
# ssc_b             OthersCentralCentralCentralCentralOthersOthers...
# hsc_p                                                       14261.6
# hsc_b             OthersOthersCentralCentralCentralOthersOthersC...
# hsc_s             CommerceScienceArtsScienceCommerceScienceComme...
# degree_p                                                    14269.6
# degree_t          Sci&TechSci&TechComm&MgmtSci&TechComm&MgmtSci&...
# workex            NoYesNoNoNoYesNoYesNoNoYesYesNoNoNoYesYesNoNoY...
# etest_p                                                     15501.6
# specialisation    Mkt&HRMkt&FinMkt&FinMkt&HRMkt&FinMkt&FinMkt&Fi...
# mba_p                                                       13389.8
# status            PlacedPlacedPlacedNot PlacedPlacedNot PlacedNo...
# ...

# %%
# to get maximum value from any columns(in my case it's salary)
print(df["salary"].max())
# Out:
# 940000.0

# %%
#to get mean of individual column
print(np.mean(df))
# Out:
# sl_no          108.000000
# ssc_p           67.303395
# hsc_p           66.333163
# degree_p        66.370186
# etest_p         72.100558
# mba_p           62.278186
# salary      288655.405405
# dtype: float64

# %%
#mean of any selected column
print(np.mean(df["salary"]))
# Out:
# 288655.4054054054

# %%
## axis=0:: for column
###axis=1::: for row
print(np.mean(df, axis=0))
print(np.mean(df, axis=1))
# Out:
# sl_no          108.000000
# ssc_p           67.303395
# hsc_p           66.333163
# degree_p        66.370186
# etest_p         72.100558
# mba_p           62.278186
# salary      288655.405405
# dtype: float64
# 0       38618.685714
# 1       28627.131429
# 2       35761.828571
# 3          48.238333
# 4       60770.000000
# 5          47.438333
# 6          51.461667
# 7       36049.877143
# 8       33055.090000
# 9          50.868333
# 10      37187.550000
# 11      35764.571429
# 12         51.173333
# 13      31196.232857
# 14         50.826667
# 15      28623.094286
# 16      42904.905714
# 17         55.213333
# 18         57.346667
# 19      33763.624286
# 20      37902.957143
# 21      56203.722857
# 22      51478.595714
# 23      42911.680000
# 24      51492.781429
# 25         54.118333
# 26      34342.078571
# 27      37907.098571
# 28      50055.322857
# 29         57.548333
# 30      35764.314286
# 31         56.553333
# 32      39764.928571
# 33      37203.968571
# ...

# %%
#sum of rows nd columns nd particular row
print(np.sum(df, axis=0))
print(np.sum(df, axis=1))
print(np.sum(df["salary"]))
# Out:
# sl_no                                                         23220
# gender            MMMMMMFMMMMMFFMFMFFMMFFFMFMMMMFFFFMFMFFMFFMMFF...
# ssc_p                                                       14470.2
# ssc_b             OthersCentralCentralCentralCentralOthersOthers...
# hsc_p                                                       14261.6
# hsc_b             OthersOthersCentralCentralCentralOthersOthersC...
# hsc_s             CommerceScienceArtsScienceCommerceScienceComme...
# degree_p                                                    14269.6
# degree_t          Sci&TechSci&TechComm&MgmtSci&TechComm&MgmtSci&...
# workex            NoYesNoNoNoYesNoYesNoNoYesYesNoNoNoYesYesNoNoY...
# etest_p                                                     15501.6
# specialisation    Mkt&HRMkt&FinMkt&FinMkt&HRMkt&FinMkt&FinMkt&Fi...
# mba_p                                                       13389.8
# status            PlacedPlacedPlacedNot PlacedPlacedNot PlacedNo...
# ...

# %%
#scatterplot
sns.pairplot(df)

# %%
sns.scatterplot(x='hsc_p', y='salary', data=df)
plt.show()
